# %%
import pandas as pd

df = pd.read_parquet(r"d:\desktop\practice_dom\FINSHARK\Alpha-Deputy\fork-zipline\data\bundles\data\backtest\all_stocks_filled.parquet")
df['date'] = pd.to_datetime(df['date'])
# 输出最小和最大日期
print("最小日期:", df['date'].min())
print("最大日期:", df['date'].max())
df.head()


# print("检查 symbol 是否有缺失")
# print(df["symbol"].isna().sum())
# # print(df[df["symbol"].isna()])
# # print(df["symbol"].value_counts(dropna=False))
# Out:
# 最小日期: 2020-08-10 00:00:00
# 最大日期: 2025-08-06 00:00:00
#         date symbol   open   high    low  close     volume  dividend  \
# 0 2020-08-10      A  97.84  97.96  96.95  97.14   900865.0       0.0
# 1 2020-08-11      A  97.22  97.63  96.20  96.30  1137000.0       0.0
# 2 2020-08-12      A  96.66  98.28  96.52  97.63  1318189.0       0.0
# 3 2020-08-13      A  97.55  99.12  97.18  98.77  1190800.0       0.0
# 4 2020-08-14      A  98.45  98.83  96.90  97.37   957400.0       0.0
#
#    split_ratio
# 0          1.0
# 1          1.0
# 2          1.0
# 3          1.0
# 4          1.0

# %%
null_count = df['split_ratio'].isnull().sum()
print("缺失值数量:", null_count)
# Out:
# 缺失值数量: 0
