# %%
import os
import sys
import pandas as pd
import numpy as np

# %%
print(os.getcwd())
# Out:
# d:\desktop\Files(2024-2025)\practice_dom\FINSHARK\Alpha-Deputy

# %%
df = pd.read_parquet(
    r"D:\desktop\Files(2024-2025)\practice_dom\FINSHARK\Alpha-Deputy\fork-zipline\new_engine_starter\src\ultimate_data\merged_ultimate_with_flag_trimmed.parquet"
)

# %%
df.head(5)
# Out:
#         date symbol  open  high  low  close  volume effective_date period_end  \
# 0 2020-08-06    XYZ   NaN   NaN  NaN    NaN     NaN            NaT        NaT
# 1 2020-08-06    SKE   NaN   NaN  NaN    NaN     NaN            NaT        NaT
# 2 2020-08-06   AMPS   NaN   NaN  NaN    NaN     NaN            NaT        NaT
# 3 2020-08-06   TSBX   NaN   NaN  NaN    NaN     NaN            NaT        NaT
# 4 2020-08-06    EXK   NaN   NaN  NaN    NaN     NaN            NaT        NaT
#
#   reportedCurrency   cik acceptedDate fiscalYear period  grossProfit  revenue  \
# 0             None  None         None       None   None          NaN      NaN
# 1             None  None         None       None   None          NaN      NaN
# 2             None  None         None       None   None          NaN      NaN
# 3             None  None         None       None   None          NaN      NaN
# 4             None  None         None       None   None          NaN      NaN
#
# ...
